# %% [markdown]
# # 🚀 E-Commerce Sales Analysis: Complete Python Project Roadmap
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 2rem; border-radius: 20px; margin: 2rem 0; text-align: center; color: white; box-shadow: 0 20px 40px rgba(0,0,0,0.1);">
# <h1 style="font-size: 2.5rem; margin: 0; text-shadow: 2px 2px 4px rgba(0,0,0,0.3);">📊 Professional Data Science Roadmap</h1>
# <p style="font-size: 1.2rem; margin: 1rem 0 0 0; opacity: 0.95;">End-to-End E-Commerce Analytics Pipeline</p>
# </div>
#
# ## 📋 Project Status
# <div style="background: #f8f9fa; border-left: 5px solid #28a745; padding: 1.5rem; margin: 2rem 0; border-radius: 10px;">
# <span style="font-size: 1.1rem; font-weight: bold; color: #28a745;">✅ Ready for Implementation</span><br>
# <small>Complete roadmap with prioritized phases and detailed deliverables</small>
# </div>
#
# ---
#
# ## 🔥 HIGH PRIORITY PHASES (Execute First)
#
# ### Phase 1: Data Preprocessing
# <div style="animation: slideInLeft 0.8s ease-out;">
# | Task | Status | Priority |
# |------|--------|----------|
# | 🔍 Outlier detection and removal | ⏳ Pending | **HIGH** |
# | 🛠️ Feature engineering (new variables) | ⏳ Pending | **HIGH** |
# | ⚖️ Data normalization/scaling | ⏳ Pending | **HIGH** |
# | 🧹 Missing value treatment | ⏳ Pending | **HIGH** |
# </div>
#
# ### Phase 2: Time Series Analysis
# <div style="animation: slideInRight 0.8s ease-out 0.2s both;">
# | Task | Status | Priority |
# |------|--------|----------|
# | 📅 Convert Order Date to datetime | ⏳ Pending | **HIGH** |
# | 📈 Sales trend analysis over time | ⏳ Pending | **HIGH** |
# | 🌊 Seasonal decomposition | ⏳ Pending | **HIGH** |
# | 📊 Monthly/quarterly reports | ⏳ Pending | **HIGH** |
# | 🔮 Time series forecasting | ⏳ Pending | **HIGH** |
# </div>
#
# ### Phase 3: Customer Analytics
# <div style="animation: slideInLeft 0.8s ease-out 0.4s both;">
# | Task | Status | Priority |
# |------|--------|----------|
# | 🏷️ RFM analysis | ⏳ Pending | **HIGH** |
# | 👥 Customer segmentation | ⏳ Pending | **HIGH** |
# | 💰 Lifetime value calculation | ⏳ Pending | **HIGH** |
# | 🔄 Repeat purchase patterns | ⏳ Pending | **HIGH** |
# | 🚪 Customer churn analysis | ⏳ Pending | **HIGH** |
# </div>
#
# ---
#
# ## ⚡ MEDIUM PRIORITY PHASES
#
# ### Phase 4: Predictive Modeling
# <div style="background: linear-gradient(90deg, #ffecd2 0%, #fcb69f 100%); padding: 1.5rem; border-radius: 15px; margin: 1.5rem 0;">
# **Priority: MEDIUM** | **Timeline: Weeks 4-6**
# - 📊 Sales forecasting models
# - 💵 Profit prediction algorithms
# - 🚪 Customer churn prediction
# - 🛒 Demand forecasting by category
# - ✅ Model evaluation & validation
# </div>
#
# ### Phase 5: Statistical Analysis
# <div style="background: linear-gradient(90deg, #a8edea 0%, #fed6e3 100%); padding: 1.5rem; border-radius: 15px; margin: 1.5rem 0;">
# **Priority: MEDIUM** | **Timeline: Weeks 6-7**
# - 🧪 A/B testing framework
# - ⚗️ Hypothesis testing
# - 📏 Confidence intervals
# - 📈 Statistical significance tests
# </div>
#
# ### Phase 6: Dashboard Creation
# <div style="background: linear-gradient(90deg, #d299c2 0%, #fef9d7 100%); padding: 1.5rem; border-radius: 15px; margin: 1.5rem 0;">
# **Priority: MEDIUM** | **Timeline: Weeks 7-8**
# - 🎨 Interactive Plotly visualizations
# - 🌐 Dash web application
# - 📱 Real-time metrics dashboard
# - 📋 Business intelligence reports
# </div>
#
# ---
#
# ## 🌟 LOW PRIORITY (Future Enhancements)
#
# <div style="background: #e3f2fd; border: 2px dashed #2196f3; padding: 2rem; border-radius: 15px; text-align: center; margin: 2rem 0;">
# <h3 style="color: #1976d2; margin-top: 0;">Phase 7: Advanced Analytics</h3>
# <span style="font-size: 1.1rem; color: #ff9800;">Priority: LOW | Timeline: Weeks 9+</span>
#
# **Future Features:**
# - 🛍️ Market basket analysis
# - 🎯 K-means clustering
# - 🤖 Advanced ML models
# - ✨ Recommendation systems
# </div>
#
# ---
#
# ## 🎯 Implementation Timeline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Details = pd.read_csv('../DataSets/Details.csv')
display(Details.head(2))

Orders = pd.read_csv('../DataSets/Orders.csv')
display(Orders.head(2))
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681    1096     658         7  Electronics  Electronic Games
# 1  B-26055    5729      64        14    Furniture            Chairs
#
#   PaymentMode
# 0         COD
# 1         EMI
#   Order ID  Order Date CustomerName          State     City
# 0  B-26055  10-03-2018    Harivansh  Uttar Pradesh  Mathura
# 1  B-25993  03-02-2018       Madhav          Delhi    Delhi
